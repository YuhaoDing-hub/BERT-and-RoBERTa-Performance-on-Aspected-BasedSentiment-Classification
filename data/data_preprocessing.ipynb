# %% [markdown]
# ## Level 1 and 2 Aspect

# %%
import json
import numpy as np
pos = [0,0]
neg = [0,0]
level1 = ['Stock', 'Market', 'Corporate', 'Economy']
level2 = ['Price Action','Technical Analysis','Options','Volatility','Sales','Financial','Coverage','Fundamentals','Dividend Policy',\
  'Reputation',\
  'Legal',\
  'Market',\
  'Strategy',\
  'M&A',\
  'Signal',\
  'Rumors',\
  'Appointment',\
  'Risks',\
  'Regulatory',\
  'IPO',\
  'Central Banks',\
  'Company Communication',\
  'Conditions',\
  'Currency',\
  'Trade',\
  'Insider Activity',\
  'Buyside']
count = [0 for i in range(len(level2))]
print(np.random.choice(level1))
with open('task1_post_ABSA_train.json', 'r') as f:
    array = json.load(f)
with open('task1_headline_ABSA_train.json', 'r') as f:
    array2 = json.load(f)
print(len(array))
print(len(array2))
import jsonlines
with jsonlines.open('task_train.jsonl', mode='w') as writer:
    idx_l = [i for i in array]
    np.random.shuffle(idx_l)
    idx_l2 = [i for i in array2]
    np.random.shuffle(idx_l2)
    for idx, i in enumerate(idx_l):
        if idx >= 355:
            continue
        final = {}
        a = array[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        #final['passage'] = " "
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        final['passage'] = [as1 + " " + as2]
        
        final['idx'] = idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
            pos[0] += 1
        else:
            final['label'] = "0"
            neg[0] += 1
        
        writer.write(final)
    for idx_, i in enumerate(idx_l2):
        if idx_ >= 540:
            continue
        final = {}
        a = array2[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        #final['passage'] = " "
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        final['passage'] = [as1 + " " + as2]
        final['idx'] = idx_ + idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
            pos[0] += 1
        else:
            final['label'] = "0"
            neg[0] += 1
        
        writer.write(final)

with jsonlines.open('task_val.jsonl', mode='w') as writer:
    
    for idx, i in enumerate(idx_l):
        if idx < 355:
            continue
        final = {}
        a = array[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        count[level2.index(as2)] += 1
        #final['passage'] = " "
        final['passage'] = [as1 + " " + as2]
        final['idx'] = idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
        else:
            final['label'] = "0"
        writer.write(final)
    for idx_, i in enumerate(idx_l2):
        if idx_ < 540:
            continue
        final = {}
        a = array2[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        #final['passage'] = " "
        final['passage'] = [as1 + " " + as2]
        count[level2.index(as2)] += 1
        
#         if len(final['passage']) >= 2:
#             final['passage'] = [final['passage'][0] + " " + final['passage'][1]]
        final['idx'] = idx_ + idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
        else:
            final['label'] = "0"
        
        writer.write(final)
# Out:
# Economy
# 675
# 436

# %%
sum(count)
# Out:
# 320

# %%
for i in range(len(count)):
    count[i] = count[i]/320

# %%
count
# Out:
# [0.584375,
#  0.134375,
#  0.021875,
#  0.00625,
#  0.025,
#  0.028125,
#  0.0625,
#  0.009375,
#  0.015625,
#  0.0,
#  0.00625,
#  0.003125,
#  0.01875,
#  0.015625,
#  0.015625,
#  0.0125,
#  0.0,
#  0.03125,
#  0.0,
#  0.0,
#  0.0,
#  0.0,
#  0.003125,
#  0.0,
#  0.0,
#  0.00625,
#  0.0]

# %%
count
# Out:
# [0.6,
#  0.3499222395023328,
#  0.023823726653303644,
#  0.0,
#  0.13418930500677073,
#  0.14063128062804922,
#  0.29388442886707544,
#  0.06889828046961946,
#  0.14774195167514786,
#  0.0,
#  0.05753890364266398,
#  0.0,
#  0.18283412948587002,
#  0.11111331590411609,
#  0.2488534330881191,
#  0.16340375694810966,
#  0.0,
#  0.6442122305524488,
#  0.1621521617801919,
#  0.0,
#  0.0,
#  0.0,
#  0.18764545533781135,
#  0.0,
#  0.0,
#  0.22139349228474237,
#  0.0]

# %% [markdown]
# ## No aspect

# %%
import json
import numpy as np
pos = [0,0]
neg = [0,0]
level1 = ['Stock', 'Market', 'Corporate', 'Economy']
level2 = ['Price Action','Technical Analysis','Options','Volatility','Sales','Financial','Coverage','Fundamentals','Dividend Policy',\
  'Reputation',\
  'Legal',\
  'Market',\
  'Strategy',\
  'M&A',\
  'Signal',\
  'Rumors',\
  'Appointment',\
  'Risks',\
  'Regulatory',\
  'IPO',\
  'Central Banks',\
  'Company Communication',\
  'Conditions',\
  'Currency',\
  'Trade',\
  'Insider Activity',\
  'Buyside']
print(np.random.choice(level1))
with open('task1_post_ABSA_train.json', 'r') as f:
    array = json.load(f)
with open('task1_headline_ABSA_train.json', 'r') as f:
    array2 = json.load(f)
print(len(array))
print(len(array2))
import jsonlines
with jsonlines.open('task_train.jsonl', mode='w') as writer:
    idx_l = [i for i in array]
    np.random.shuffle(idx_l)
    idx_l2 = [i for i in array2]
    np.random.shuffle(idx_l2)
    for idx, i in enumerate(idx_l):
        if idx >= 355:
            continue
        final = {}
        a = array[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        final['passage'] = " "
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        #final['passage'] = [as1 + " " + np.random.choice(level2)]
        
            
#         if len(final['passage']) >= 2:
#             final['passage'] = [final['passage'][0] + " " + final['passage'][1]]
        final['idx'] = idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
            pos[0] += 1
        else:
            final['label'] = "0"
            neg[0] += 1
        
        writer.write(final)
    for idx_, i in enumerate(idx_l2):
        if idx_ >= 540:
            continue
        final = {}
        a = array2[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        final['passage'] = " "
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        #final['passage'] = [as1 + " " + np.random.choice(level2)]
#         if len(final['passage']) >= 2:
#             final['passage'] = [final['passage'][0] + " " + final['passage'][1]]
        final['idx'] = idx_ + idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
            pos[0] += 1
        else:
            final['label'] = "0"
            neg[0] += 1
        
        writer.write(final)

with jsonlines.open('task_val.jsonl', mode='w') as writer:
    
    for idx, i in enumerate(idx_l):
        if idx < 355:
            continue
        final = {}
        a = array[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        final['passage'] = " "
        #final['passage'] = [as1 + " " + np.random.choice(level2)]
#         if len(final['passage']) >= 2:
#             final['passage'] = [final['passage'][0] + " " + final['passage'][1]]
        final['idx'] = idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
        else:
            final['label'] = "0"
        writer.write(final)
    for idx_, i in enumerate(idx_l2):
        if idx_ < 540:
            continue
        final = {}
        a = array2[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        final['passage'] = " "
        #final['passage'] = [as1 + " " + np.random.choice(level2)]
#         if len(final['passage']) >= 2:
#             final['passage'] = [final['passage'][0] + " " + final['passage'][1]]
        final['idx'] = idx_ + idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
        else:
            final['label'] = "0"
        
        writer.write(final)
# Out:
# Economy
# 675
# 436

# %% [markdown]
# ## Level 1 Aspect

# %%
import json
import numpy as np
pos = [0,0]
neg = [0,0]
level1 = ['Stock', 'Market', 'Corporate', 'Economy']
level2 = ['Price Action','Technical Analysis','Options','Volatility','Sales','Financial','Coverage','Fundamentals','Dividend Policy',\
  'Reputation',\
  'Legal',\
  'Market',\
  'Strategy',\
  'M&A',\
  'Signal',\
  'Rumors',\
  'Appointment',\
  'Risks',\
  'Regulatory',\
  'IPO',\
  'Central Banks',\
  'Company Communication',\
  'Conditions',\
  'Currency',\
  'Trade',\
  'Insider Activity',\
  'Buyside']
print(np.random.choice(level1))
with open('task1_post_ABSA_train.json', 'r') as f:
    array = json.load(f)
with open('task1_headline_ABSA_train.json', 'r') as f:
    array2 = json.load(f)
print(len(array))
print(len(array2))
import jsonlines
with jsonlines.open('task_train.jsonl', mode='w') as writer:
    idx_l = [i for i in array]
    np.random.shuffle(idx_l)
    idx_l2 = [i for i in array2]
    np.random.shuffle(idx_l2)
    for idx, i in enumerate(idx_l):
        if idx >= 355:
            continue
        final = {}
        a = array[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        #final['passage'] = " "
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        final['passage'] = [as1]
        
            
#         if len(final['passage']) >= 2:
#             final['passage'] = [final['passage'][0] + " " + final['passage'][1]]
        final['idx'] = idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
            pos[0] += 1
        else:
            final['label'] = "0"
            neg[0] += 1
        
        writer.write(final)
    for idx_, i in enumerate(idx_l2):
        if idx_ >= 540:
            continue
        final = {}
        a = array2[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        final['passage'] = " "
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        final['passage'] = [as1]
#         if len(final['passage']) >= 2:
#             final['passage'] = [final['passage'][0] + " " + final['passage'][1]]
        final['idx'] = idx_ + idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
            pos[0] += 1
        else:
            final['label'] = "0"
            neg[0] += 1
        
        writer.write(final)

with jsonlines.open('task_val.jsonl', mode='w') as writer:
    
    for idx, i in enumerate(idx_l):
        if idx < 355:
            continue
        final = {}
        a = array[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        #final['passage'] = " "
        final['passage'] = [as1]
#         if len(final['passage']) >= 2:
#             final['passage'] = [final['passage'][0] + " " + final['passage'][1]]
        final['idx'] = idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
        else:
            final['label'] = "0"
        writer.write(final)
    for idx_, i in enumerate(idx_l2):
        if idx_ < 540:
            continue
        final = {}
        a = array2[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        #final['passage'] = " "
        final['passage'] = [as1]
#         if len(final['passage']) >= 2:
#             final['passage'] = [final['passage'][0] + " " + final['passage'][1]]
        final['idx'] = idx_ + idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
        else:
            final['label'] = "0"
        
        writer.write(final)
# Out:
# Market
# 675
# 436

# %% [markdown]
# ## Level 2 Aspect

# %%
import json
import numpy as np
pos = [0,0]
neg = [0,0]
level1 = ['Stock', 'Market', 'Corporate', 'Economy']
level2 = ['Price Action','Technical Analysis','Options','Volatility','Sales','Financial','Coverage','Fundamentals','Dividend Policy',\
  'Reputation',\
  'Legal',\
  'Market',\
  'Strategy',\
  'M&A',\
  'Signal',\
  'Rumors',\
  'Appointment',\
  'Risks',\
  'Regulatory',\
  'IPO',\
  'Central Banks',\
  'Company Communication',\
  'Conditions',\
  'Currency',\
  'Trade',\
  'Insider Activity',\
  'Buyside']
print(np.random.choice(level1))
with open('task1_post_ABSA_train.json', 'r') as f:
    array = json.load(f)
with open('task1_headline_ABSA_train.json', 'r') as f:
    array2 = json.load(f)
print(len(array))
print(len(array2))
import jsonlines
with jsonlines.open('task_train.jsonl', mode='w') as writer:
    idx_l = [i for i in array]
    np.random.shuffle(idx_l)
    idx_l2 = [i for i in array2]
    np.random.shuffle(idx_l2)
    for idx, i in enumerate(idx_l):
        if idx >= 355:
            continue
        final = {}
        a = array[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        #final['passage'] = " "
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        final['passage'] = [as2]
        
        
            
#         if len(final['passage']) >= 2:
#             final['passage'] = [final['passage'][0] + " " + final['passage'][1]]
        final['idx'] = idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
            pos[0] += 1
        else:
            final['label'] = "0"
            neg[0] += 1
        
        writer.write(final)
    for idx_, i in enumerate(idx_l2):
        if idx_ >= 540:
            continue
        final = {}
        a = array2[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        final['passage'] = " "
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        final['passage'] = [as2]
#         if len(final['passage']) >= 2:
#             final['passage'] = [final['passage'][0] + " " + final['passage'][1]]
        final['idx'] = idx_ + idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
            pos[0] += 1
        else:
            final['label'] = "0"
            neg[0] += 1
        
        writer.write(final)

with jsonlines.open('task_val.jsonl', mode='w') as writer:
    
    for idx, i in enumerate(idx_l):
        if idx < 355:
            continue
        final = {}
        a = array[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        #final['passage'] = " "
        final['passage'] = [as2]
        if as2 != "Price Action":
            continue
#         if len(final['passage']) >= 2:
#             final['passage'] = [final['passage'][0] + " " + final['passage'][1]]
        final['idx'] = idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
        else:
            final['label'] = "0"
        writer.write(final)
    for idx_, i in enumerate(idx_l2):
        if idx_ < 540:
            continue
        final = {}
        a = array2[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        #final['passage'] = " "
        final['passage'] = [as2]
        
        if as2 != "Price Action":
            continue
#         if len(final['passage']) >= 2:
#             final['passage'] = [final['passage'][0] + " " + final['passage'][1]]
        final['idx'] = idx_ + idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
        else:
            final['label'] = "0"
        
        writer.write(final)
# Out:
# Market
# 675
# 436

# %% [markdown]
# ## Level 1 and 2 Randomize

# %%
import json
import numpy as np
pos = [0,0]
neg = [0,0]
level1 = ['Stock', 'Market', 'Corporate', 'Economy']
level2 = ['Price Action','Technical Analysis','Options','Volatility','Sales','Financial','Coverage','Fundamentals','Dividend Policy',\
  'Reputation',\
  'Legal',\
  'Market',\
  'Strategy',\
  'M&A',\
  'Signal',\
  'Rumors',\
  'Appointment',\
  'Risks',\
  'Regulatory',\
  'IPO',\
  'Central Banks',\
  'Company Communication',\
  'Conditions',\
  'Currency',\
  'Trade',\
  'Insider Activity',\
  'Buyside']
print(np.random.choice(level1))
with open('task1_post_ABSA_train.json', 'r') as f:
    array = json.load(f)
with open('task1_headline_ABSA_train.json', 'r') as f:
    array2 = json.load(f)
print(len(array))
print(len(array2))
import jsonlines
with jsonlines.open('task_train.jsonl', mode='w') as writer:
    idx_l = [i for i in array]
    np.random.shuffle(idx_l)
    idx_l2 = [i for i in array2]
    np.random.shuffle(idx_l2)
    for idx, i in enumerate(idx_l):
        if idx >= 355:
            continue
        final = {}
        a = array[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        #final['passage'] = " "
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        final['passage'] = [np.random.choice(level1) + " " + np.random.choice(level2)]
        
        final['idx'] = idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
            pos[0] += 1
        else:
            final['label'] = "0"
            neg[0] += 1
        
        writer.write(final)
    for idx_, i in enumerate(idx_l2):
        if idx_ >= 540:
            continue
        final = {}
        a = array2[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        #final['passage'] = " "
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        final['passage'] = [np.random.choice(level1) + " " + np.random.choice(level2)]
        final['idx'] = idx_ + idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
            pos[0] += 1
        else:
            final['label'] = "0"
            neg[0] += 1
        
        writer.write(final)

with jsonlines.open('task_val.jsonl', mode='w') as writer:
    
    for idx, i in enumerate(idx_l):
        if idx < 355:
            continue
        final = {}
        a = array[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        #final['passage'] = " "
        final['passage'] = [np.random.choice(level1) + " " + np.random.choice(level2)]
        final['idx'] = idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
        else:
            final['label'] = "0"
        writer.write(final)
    for idx_, i in enumerate(idx_l2):
        if idx_ < 540:
            continue
        final = {}
        a = array2[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        #final['passage'] = " "
        final['passage'] = [np.random.choice(level1) + " " + np.random.choice(level2)]
#         if len(final['passage']) >= 2:
#             final['passage'] = [final['passage'][0] + " " + final['passage'][1]]
        final['idx'] = idx_ + idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
        else:
            final['label'] = "0"
        
        writer.write(final)
# Out:
# Corporate
# 675
# 436

# %% [markdown]
# ## Only 2 Randomize

# %%
import json
import numpy as np
pos = [0,0]
neg = [0,0]
level1 = ['Stock', 'Market', 'Corporate', 'Economy']
level2 = ['Price Action','Technical Analysis','Options','Volatility','Sales','Financial','Coverage','Fundamentals','Dividend Policy',\
  'Reputation',\
  'Legal',\
  'Market',\
  'Strategy',\
  'M&A',\
  'Signal',\
  'Rumors',\
  'Appointment',\
  'Risks',\
  'Regulatory',\
  'IPO',\
  'Central Banks',\
  'Company Communication',\
  'Conditions',\
  'Currency',\
  'Trade',\
  'Insider Activity',\
  'Buyside']
print(np.random.choice(level1))
with open('task1_post_ABSA_train.json', 'r') as f:
    array = json.load(f)
with open('task1_headline_ABSA_train.json', 'r') as f:
    array2 = json.load(f)
print(len(array))
print(len(array2))
import jsonlines
with jsonlines.open('task_train.jsonl', mode='w') as writer:
    idx_l = [i for i in array]
    np.random.shuffle(idx_l)
    idx_l2 = [i for i in array2]
    np.random.shuffle(idx_l2)
    for idx, i in enumerate(idx_l):
        if idx >= 355:
            continue
        final = {}
        a = array[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        #final['passage'] = " "
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        final['passage'] = [np.random.choice(level2)]
        
        final['idx'] = idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
            pos[0] += 1
        else:
            final['label'] = "0"
            neg[0] += 1
        
        writer.write(final)
    for idx_, i in enumerate(idx_l2):
        if idx_ >= 540:
            continue
        final = {}
        a = array2[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        #final['passage'] = " "
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        final['passage'] = [np.random.choice(level2)]
        final['idx'] = idx_ + idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
            pos[0] += 1
        else:
            final['label'] = "0"
            neg[0] += 1
        
        writer.write(final)

with jsonlines.open('task_val.jsonl', mode='w') as writer:
    
    for idx, i in enumerate(idx_l):
        if idx < 355:
            continue
        final = {}
        a = array[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        #final['passage'] = " "
        final['passage'] = [np.random.choice(level2)]
        final['idx'] = idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
        else:
            final['label'] = "0"
        writer.write(final)
    for idx_, i in enumerate(idx_l2):
        if idx_ < 540:
            continue
        final = {}
        a = array2[i]
        final['question'] = a['sentence']
        info = a['info'][0]
        as1 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[0]
        as2 = info['aspects'].strip('[').strip(']').strip('\'').split('/')[1]
        #final['passage'] = " "
        final['passage'] = [np.random.choice(level2)]
#         if len(final['passage']) >= 2:
#             final['passage'] = [final['passage'][0] + " " + final['passage'][1]]
        final['idx'] = idx_ + idx
        if float(info['sentiment_score']) > 0:
            final['label'] = "1"
        else:
            final['label'] = "0"
        
        writer.write(final)


print('done')
# Out:
# Stock
# 675
# 436
# done

# %%
# Out:
# 1277

# %%
with jsonlines.open('task_train.jsonl') as reader:
    for obj in reader:
        print(obj)
# Out:
# {'question': '$VIPS similar pattern like beginning of May. Did u sell? Same now..will go up much higher after this drop.', 'passage': ['Price Action'], 'idx': 0, 'label': '1'}
# {'question': '@ACInvestorBlog: $SPY eod run :)', 'passage': ['Price Action'], 'idx': 1, 'label': '1'}
# {'question': '$AAPL AAPL finally breaking under the 49 M.A.. With no buybacks this week, look for AAPL to test the 120 support area.', 'passage': ['Price Action'], 'idx': 2, 'label': '0'}
# {'question': '$LNT Increases Annual Dividend Target to $1.80/Share from $1.70/Share', 'passage': ['Dividend Policy'], 'idx': 3, 'label': '1'}
# {'question': 'Maglan Capital Up +20.84% In February, Long Fairpoint  http://stks.co/s1eQc $$ $FRP', 'passage': ['Price Action'], 'idx': 4, 'label': '1'}
# {'question': '$BBRY hearing rumours of a major joint venture announcement.', 'passage': ['Rumors'], 'idx': 5, 'label': '1'}
# ...

# %%
with jsonlines.open('task_val.jsonl') as reader:
    for obj in reader:
        print(obj)
# Out:
# {'question': "Entering long Lockheed Martin $LMT at Thursday's open. http://stks.co/eXtA", 'passage': ['Stock Price Action'], 'idx': 355, 'label': '1'}
# {'question': '$VIPS similar pattern like beginning of May. Did u sell? Same now..will go up much higher after this drop.', 'passage': ['Stock Price Action'], 'idx': 357, 'label': '1'}
# {'question': '$MXWL Oh snap. Just went long again. LT', 'passage': ['Stock Price Action'], 'idx': 358, 'label': '1'}
# {'question': '$DMND green and moving', 'passage': ['Stock Price Action'], 'idx': 359, 'label': '1'}
# {'question': 'expecting  $SPY to close above 205.20 $AAPL', 'passage': ['Stock Price Action'], 'idx': 360, 'label': '1'}
# {'question': "$SPY Don't hang your bull hat yet. Next week we will pop higher on QE3 hope on back of fed's 2 day meeting.", 'passage': ['Stock Price Action'], 'idx': 362, 'label': '1'}
# ...

# %%
pos, neg
# Out:
# ([520, 0], [271, 0])

# %%
436 + 675
# Out:
# 1111

# %%
355 + 81
# Out:
# 436

# %%
l = [1,2,3,4]
l = l[0:2]
l
# Out:
# [1, 2]
